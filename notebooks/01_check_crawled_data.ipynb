# %% [markdown]
# # 01 - Check Crawled Data
# Notebook kiểm tra nhanh dữ liệu crawl và relevance filter.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))
from src.storage.db import query_dataframe
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 from pathlib import Path
#       3 sys.path.append(str(Path('..').resolve()))
# ----> 4 from src.storage.db import query_dataframe
#
# File E:\project sentiment 3t\market_sentiment_demo\src\storage\db.py:10
#       7 from typing import Any
#       9 import pandas as pd
# ---> 10 from dotenv import load_dotenv
#      11 from sqlalchemy import create_engine, text
#      12 from sqlalchemy.engine import Engine
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
articles = query_dataframe('SELECT * FROM articles')
relevance = query_dataframe('SELECT * FROM article_relevance')
len(articles), len(relevance)

# %%
articles.groupby('category').size().sort_values(ascending=False)

# %%
articles.assign(content_len=articles['content'].fillna('').str.len())['content_len'].describe()

# %%
articles[['published_at','category','title','status','url']].tail(20)

# %%
relevance[relevance['decision']=='skip_sentiment'].head(20)

# %%
relevance[relevance['decision']=='process_sentiment'].head(20)
